# %% [markdown]
# # Jupyter Notebook dedicated to testing functionalities

# %% [markdown]
# <strong>test: videosup.py - video_explore <strong>

# %%
import cv2
from ultralytics import YOLO
from ultralytics.solutions import ObjectCounter

# %%
from videosup import video_explore

video_explore(vidpath="datasets/Sideseeing/Sideseeing_TestData/video.mp4", set_fps=True, vid_fps=250, window_size=(320,480))
# Out:
# waitkey delay: 4
# Window closed by the user.
# Video Explore Execution was Successful
# Video Explore Execution Ended

# %%
from videosup import apply_YoloLive
apply_YoloLive(yolo_model="yolo11n.pt")
# Out:
# 0: 480x640 1 person, 310.4ms
# Speed: 13.6ms preprocess, 310.4ms inference, 26.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 189.5ms
# Speed: 4.0ms preprocess, 189.5ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.4ms
# Speed: 3.2ms preprocess, 144.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 140.4ms
# Speed: 6.0ms preprocess, 140.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 137.3ms
# Speed: 2.9ms preprocess, 137.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 141.6ms
# Speed: 3.0ms preprocess, 141.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 140.5ms
# Speed: 3.0ms preprocess, 140.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 119.9ms
# ...

# %%
from videosup import apply_YoloCounter

# %%
apply_YoloCounter(counter_region=[(400,200),(800,200),(900,400),(800,600),(400,600)], 
                yolo_model="yolo11n.pt",
                vidpath="datasets/Streetaware/left_half.mp4",
                frame_size=(1200,900))
# Out:
# retrieved FPS: 14
# waitkey delay: 71
# Ultralytics Solutions:  {'model': 'yolo11n.pt', 'region': [(400, 200), (800, 200), (900, 400), (800, 600), (400, 600)], 'line_width': 2, 'show': False, 'show_in': True, 'show_out': True, 'classes': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'colormap': None, 'analytics_type': 'line', 'json_file': None}
#
# 0: 480x640 1 person, 1 car, 1 truck, 137.5ms
# Speed: 6.0ms preprocess, 137.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 truck, 195.9ms
# Speed: 6.0ms preprocess, 195.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 128.5ms
# Speed: 6.2ms preprocess, 128.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# WARNING  no tracks found!
#
# 0: 480x640 1 person, 1 car, 1 truck, 122.6ms
# Speed: 4.0ms preprocess, 122.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
from videosup import apply_YoloTracker

apply_YoloTracker(vidpath="datasets/Streetaware/left_half.mp4", set_fps=False)
# Out:
# retrieved FPS: 14.40299572039943
# waitkey delay: 69
#
# 0: 480x640 2 persons, 2 cars, 140.7ms
# Speed: 6.0ms preprocess, 140.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 110.1ms
# Speed: 5.0ms preprocess, 110.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 107.7ms
# Speed: 6.0ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 118.4ms
# Speed: 5.0ms preprocess, 118.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 110.0ms
# Speed: 4.6ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 143.4ms
# Speed: 7.0ms preprocess, 143.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 104.1ms
# ...

# %%
# Out:
# retrieved FPS: 30.004007258915692
# waitkey delay: 33
# Ultralytics Solutions:  {'model': 'yolo11n.pt', 'region': [(20, 50), (160, 50), (160, 420), (20, 420)], 'line_width': 2, 'show': False, 'show_in': True, 'show_out': True, 'classes': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'colormap': None, 'analytics_type': 'line', 'json_file': None}
#
# 0: 640x448 2 cars, 114.2ms
# Speed: 0.0ms preprocess, 114.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
# (480, 320, 3)
#
# 0: 640x448 2 cars, 188.1ms
# Speed: 0.0ms preprocess, 188.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
# (480, 320, 3)
#
# 0: 640x448 2 cars, 90.5ms
# Speed: 2.0ms preprocess, 90.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
# (480, 320, 3)
#
# 0: 640x448 2 cars, 94.7ms
# Speed: 3.0ms preprocess, 94.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
# (480, 320, 3)
#
# 0: 640x448 2 cars, 98.9ms
# ...

# %%
import numpy as np

window_size=np.array([5,10])
frame_size=np.array([2,2])
counter_region=([(20,50),(160,50),(160,420),(20,420)])


(counter_region/frame_size)*window_size
# Out:
# array([[         50,         250],
#        [        400,         250],
#        [        400,        2100],
#        [         50,        2100]])
